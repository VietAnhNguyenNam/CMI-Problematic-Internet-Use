# %% [markdown]
# # Import libraries

# %%
import os
from pathlib import Path
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

import pandas as pd
import numpy as np
from  lightgbm import LGBMClassifier,log_evaluation,early_stopping, LGBMRegressor
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import StackingRegressor
import warnings
warnings.filterwarnings('ignore')
from sklearn.impute import SimpleImputer

from sklearn.metrics import make_scorer, cohen_kappa_score
import optuna

#config
class Config():
    seed=2024
    num_folds=10
    TARGET_NAME ='sii'
import random

def seed_everything(seed):
    np.random.seed(seed)
    random.seed(seed)
seed_everything(Config.seed)

# %% [markdown]
# # read data

# %%
# define helper functions to read parquet files
def process_file(filename, dirname):
    df = pd.read_parquet(os.path.join(dirname, filename, 'part-0.parquet'))
    df.drop('step', axis=1, inplace=True)
    
    return df.describe().values.reshape(-1), filename.split('=')[1]

def load_time_series(dirname):
    ids = os.listdir(dirname)
    
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(lambda fname: process_file(fname, dirname), ids), total=len(ids)))
    
    stats, indexes = zip(*results)
    df = pd.DataFrame(stats, columns=[f"stat_{i}" for i in range(len(stats[0]))])
    df['id'] = indexes
    
    return df

root = Path('/kaggle/input/child-mind-institute-problematic-internet-use')

# read data
train=pd.read_csv(root / "train.csv")
train = train.dropna(subset=['sii'])    # drop record has sii = NaN
test=pd.read_csv(root / "test.csv")

ts_train = load_time_series(root / "series_train.parquet")
ts_test = load_time_series(root / "series_test.parquet")
time_series_cols = ts_train.columns.tolist()
time_series_cols.remove("id")
            
# merge data
train = pd.merge(train, ts_train, how="left", on='id')
test = pd.merge(test, ts_test, how="left", on='id')
train = train.set_index('id')
test = test.set_index('id')

# group common columns
cat_cols = ['Basic_Demos-Enroll_Season', 'CGAS-Season', 'Physical-Season', 'Fitness_Endurance-Season', 'FGC-Season', 'BIA-Season', 'PAQ_A-Season', 'PAQ_C-Season', 'SDS-Season', 'PreInt_EduHx-Season']
num_cols = ['Basic_Demos-Age', 'Basic_Demos-Sex', 'CGAS-CGAS_Score', 'Physical-BMI', 'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference', 'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP', 'Fitness_Endurance-Max_Stage', 'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU', 'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR', 'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI', 'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM', 'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num', 'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM', 'BIA-BIA_TBW', 'PAQ_A-PAQ_A_Total', 'PAQ_C-PAQ_C_Total', 'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T', 'PreInt_EduHx-computerinternet_hoursday']
tabular_cols = ['Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex', 'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI', 'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference', 'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP', 'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage', 'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec', 'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU', 'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR', 'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season', 'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI', 'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM', 'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num', 'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM', 'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season', 'PAQ_C-PAQ_C_Total', 'SDS-Season', 'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T', 'PreInt_EduHx-Season', 'PreInt_EduHx-computerinternet_hoursday']
# target_col = 'PCIAT-PCIAT_Total'
target_col = 'sii'
feature_cols = tabular_cols + time_series_cols
num_cols = num_cols + time_series_cols
# Out:
# 100%|██████████| 996/996 [01:10<00:00, 14.04it/s]
# 100%|██████████| 2/2 [00:00<00:00, 11.00it/s]

# %% [markdown]
# # Imputation for numeric columns

# %%
# perform mean imputation for numerical values
# categorical values shouldn't be imputed since they are all "season of participation" 

imputer = SimpleImputer(
    strategy='mean',
)
train[num_cols] = imputer.fit_transform(train[num_cols])
test[num_cols] = imputer.transform(test[num_cols])

# train.head()

# %% [markdown]
# # Feature engineer

# %%
# convert categorical values to number

def FE(df):
    
    print("Basic_Demos-Enroll_Season feature")
    col2count={'Spring': 734, 'Fall': 676, 'Winter': 676, 'Summer': 650}
    for u,v in col2count.items():
        df[f'Basic_Demos-Enroll_Season_{u}']=(df['Basic_Demos-Enroll_Season']==u).astype(np.int8)
    df['Basic_Demos-Enroll_Season']=df['Basic_Demos-Enroll_Season'].apply(lambda x:col2count.get(x,0))
    
    print("CGAS-Season feature")
    col2count={'Spring': 665, 'Fall': 583, 'Summer': 559, 'Winter': 535}
    for u,v in col2count.items():
        df[f'CGAS-Season_{u}']=(df['CGAS-Season']==u).astype(np.int8)
    df['CGAS-Season']=df['CGAS-Season'].apply(lambda x:col2count.get(x,0))
    
    print("Physical-Season feature")
    col2count={'Spring': 709, 'Fall': 650, 'Winter': 634, 'Summer': 602}
    for u,v in col2count.items():
        df[f'Physical-Season_{u}']=(df['Physical-Season']==u).astype(np.int8)
    df['Physical-Season']=df['Physical-Season'].apply(lambda x:col2count.get(x,0))
    
    print("Fitness_Endurance-Season feature")
    col2count={'Spring': 377, 'Winter': 331, 'Fall': 316, 'Summer': 236}
    for u,v in col2count.items():
        df[f'Fitness_Endurance-Season_{u}']=(df['Fitness_Endurance-Season']==u).astype(np.int8)
    df['Fitness_Endurance-Season']=df['Fitness_Endurance-Season'].apply(lambda x:col2count.get(x,0))
    
    print("FGC-Season feature")
    col2count={'Spring': 771, 'Summer': 659, 'Fall': 633, 'Winter': 584}
    for u,v in col2count.items():
        df[f'FGC-Season_{u}']=(df['FGC-Season']==u).astype(np.int8)
    df['FGC-Season']=df['FGC-Season'].apply(lambda x:col2count.get(x,0))
    
    print("BIA-Season feature")
    col2count={'Summer': 585, 'Fall': 511, 'Spring': 405, 'Winter': 343}
    for u,v in col2count.items():
        df[f'BIA-Season_{u}']=(df['BIA-Season']==u).astype(np.int8)
    df['BIA-Season']=df['BIA-Season'].apply(lambda x:col2count.get(x,0))
    
    print("PAQ_A-Season feature")
    col2count={'Winter': 98, 'Summer': 97, 'Spring': 90, 'Fall': 78}   
    for u,v in col2count.items():
        df[f'PAQ_A-Season_{u}']=(df['PAQ_A-Season']==u).astype(np.int8)
    df['PAQ_A-Season']=df['PAQ_A-Season'].apply(lambda x:col2count.get(x,0))
    
    print("PAQ_C-Season feature")
    col2count={'Spring': 405, 'Winter': 385, 'Summer': 342, 'Fall': 308}
    for u,v in col2count.items():
        df[f'PAQ_C-Season_{u}']=(df['PAQ_C-Season']==u).astype(np.int8)
    df['PAQ_C-Season']=df['PAQ_C-Season'].apply(lambda x:col2count.get(x,0))
    
    print("SDS-Season feature")
    col2count={'Spring': 692, 'Winter': 629, 'Fall': 605, 'Summer': 601}
    for u,v in col2count.items():
        df[f'SDS-Season_{u}']=(df['SDS-Season']==u).astype(np.int8)
    df['SDS-Season']=df['SDS-Season'].apply(lambda x:col2count.get(x,0))
    
    print("PreInt_EduHx-Season feature")
    col2count={'Spring': 728, 'Fall': 684, 'Winter': 655, 'Summer': 652}
    for u,v in col2count.items():
        df[f'PreInt_EduHx-Season_{u}']=(df['PreInt_EduHx-Season']==u).astype(np.int8)
    df['PreInt_EduHx-Season']=df['PreInt_EduHx-Season'].apply(lambda x:col2count.get(x,0)) 

    # test_lack_cols=['PCIAT-Season', 'PCIAT-PCIAT_01', 'PCIAT-PCIAT_02', 'PCIAT-PCIAT_03', 'PCIAT-PCIAT_04', 'PCIAT-PCIAT_05', 'PCIAT-PCIAT_06', 'PCIAT-PCIAT_07', 'PCIAT-PCIAT_08', 'PCIAT-PCIAT_09', 'PCIAT-PCIAT_10', 'PCIAT-PCIAT_11', 'PCIAT-PCIAT_12', 'PCIAT-PCIAT_13', 'PCIAT-PCIAT_14', 'PCIAT-PCIAT_15', 'PCIAT-PCIAT_16', 'PCIAT-PCIAT_17', 'PCIAT-PCIAT_18', 'PCIAT-PCIAT_19', 'PCIAT-PCIAT_20', 'PCIAT-PCIAT_Total']
    # df.drop(['id',]+test_lack_cols,axis=1,inplace=True,errors='ignore')
    # print("-"*30)
    return df

    
train=FE(train)
test=FE(test)
# train.head()
# Out:
# Basic_Demos-Enroll_Season feature
# CGAS-Season feature
# Physical-Season feature
# Fitness_Endurance-Season feature
# FGC-Season feature
# BIA-Season feature
# PAQ_A-Season feature
# PAQ_C-Season feature
# SDS-Season feature
# PreInt_EduHx-Season feature
# Basic_Demos-Enroll_Season feature
# CGAS-Season feature
# Physical-Season feature
# Fitness_Endurance-Season feature
# FGC-Season feature
# BIA-Season feature
# PAQ_A-Season feature
# PAQ_C-Season feature
# SDS-Season feature
# PreInt_EduHx-Season feature

# %% [markdown]
# # Objective function

# %%
## kappa scorer perform worse than default scoring metric in tuning hyperparameters in the current set up
# KAPPA_SCORER = make_scorer(
#     cohen_kappa_score, 
#     greater_is_better=True, 
#     weights='quadratic',
# )

def lgb_objective(trial):
    params = {
        "boosting_type": "gbdt",
        'random_state': 2024, 
        'objective': 'multiclass',
        # 'num_class': 4,
        "verbosity": -1,
        'n_estimators': trial.suggest_int('n_estimators', 32, 1024),
        'learning_rate': trial.suggest_float('learning_rate', 1e-2, 1e-1, log=True),
        'max_depth': trial.suggest_int('max_depth', 4, 8),
        'num_leaves': trial.suggest_int('num_leaves', 16, 256),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 5, 100),
        # 'feature_fraction': trial.suggest_int('feature_fraction', 0.5, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-3, 10.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-3, 10.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.5, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0), 
        'subsample': trial.suggest_int('subsample', 0.5, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 50),
    }

    X = train[feature_cols]
    y = train[target_col]
    cv = StratifiedKFold(5, shuffle=True, random_state=2024)

    val_scores = cross_val_score(
        estimator=LGBMClassifier(**params), 
        X=X, y=y, 
        cv=cv, 
        # scoring=KAPPA_SCORER,
    )

    return np.mean(val_scores)

# %% [markdown]
# # Optuna - Hyperparameters optimization

# %%
# study = optuna.create_study(direction='maximize', study_name='Classifier')
# study.optimize(lgb_objective, n_trials=100, show_progress_bar=True)
# study.best_params
# Out:
# [I 2025-01-01 08:52:07,705] A new study created in memory with name: Classifier
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-01-01 08:52:14,607] Trial 0 finished with value: 0.5964918133415178 and parameters: {'n_estimators': 361, 'learning_rate': 0.03257067253183902, 'max_depth': 7, 'num_leaves': 198, 'min_data_in_leaf': 76, 'bagging_fraction': 0.4706540787503134, 'bagging_freq': 5, 'lambda_l1': 4.547273194004619, 'lambda_l2': 0.017137984233384366, 'reg_alpha': 0.9079205204030059, 'reg_lambda': 0.8531662582934991, 'colsample_bytree': 0.5720705889236004, 'subsample': 1, 'min_child_samples': 31}. Best is trial 0 with value: 0.5964918133415178.
# [I 2025-01-01 08:52:32,181] Trial 1 finished with value: 0.5687172233416512 and parameters: {'n_estimators': 1014, 'learning_rate': 0.09924168236476032, 'max_depth': 7, 'num_leaves': 16, 'min_data_in_leaf': 98, 'bagging_fraction': 0.5255857596611084, 'bagging_freq': 1, 'lambda_l1': 0.0265490041637646, 'lambda_l2': 0.012294612062670988, 'reg_alpha': 0.573547578556282, 'reg_lambda': 0.6271451119630835, 'colsample_bytree': 0.8335258036782047, 'subsample': 0, 'min_child_samples': 33}. Best is trial 0 with value: 0.5964918133415178.
# [I 2025-01-01 08:52:35,186] Trial 2 finished with value: 0.604168723895435 and parameters: {'n_estimators': 139, 'learning_rate': 0.026961583463430888, 'max_depth': 7, 'num_leaves': 93, 'min_data_in_leaf': 97, 'bagging_fraction': 0.6226483274025397, 'bagging_freq': 1, 'lambda_l1': 1.1628531802479642, 'lambda_l2': 0.6735436120067982, 'reg_alpha': 0.7250276501850721, 'reg_lambda': 0.8373936409570579, 'colsample_bytree': 0.7918958735455295, 'subsample': 1, 'min_child_samples': 37}. Best is trial 2 with value: 0.604168723895435.
# [I 2025-01-01 08:52:53,481] Trial 3 finished with value: 0.5877153418113399 and parameters: {'n_estimators': 651, 'learning_rate': 0.04081080028932, 'max_depth': 4, 'num_leaves': 99, 'min_data_in_leaf': 38, 'bagging_fraction': 0.6398421781920212, 'bagging_freq': 2, 'lambda_l1': 0.027767988280064576, 'lambda_l2': 0.5788626294907713, 'reg_alpha': 0.5180748816069187, 'reg_lambda': 0.565639109998239, 'colsample_bytree': 0.9950327877680845, 'subsample': 0, 'min_child_samples': 19}. Best is trial 2 with value: 0.604168723895435.
# [I 2025-01-01 08:53:19,011] Trial 4 finished with value: 0.5924685410800784 and parameters: {'n_estimators': 292, 'learning_rate': 0.04755311492243271, 'max_depth': 7, 'num_leaves': 50, 'min_data_in_leaf': 7, 'bagging_fraction': 0.8692933144020527, 'bagging_freq': 7, 'lambda_l1': 0.24273737956397823, 'lambda_l2': 0.0011871759010943668, 'reg_alpha': 0.8304276277225785, 'reg_lambda': 0.5234241490628193, 'colsample_bytree': 0.956062028503877, 'subsample': 0, 'min_child_samples': 26}. Best is trial 2 with value: 0.604168723895435.
# [I 2025-01-01 08:53:27,344] Trial 5 finished with value: 0.5833357797675441 and parameters: {'n_estimators': 349, 'learning_rate': 0.09429890712853381, 'max_depth': 7, 'num_leaves': 46, 'min_data_in_leaf': 91, 'bagging_fraction': 0.6382510999046916, 'bagging_freq': 6, 'lambda_l1': 0.005781478961922227, 'lambda_l2': 0.04365678011508957, 'reg_alpha': 0.5323737775422734, 'reg_lambda': 0.6510350776654921, 'colsample_bytree': 0.8190195717107196, 'subsample': 1, 'min_child_samples': 27}. Best is trial 2 with value: 0.604168723895435.
# [I 2025-01-01 08:53:41,632] Trial 6 finished with value: 0.6067248028396429 and parameters: {'n_estimators': 523, 'learning_rate': 0.01294650828224923, 'max_depth': 7, 'num_leaves': 253, 'min_data_in_leaf': 49, 'bagging_fraction': 0.8967771964415144, 'bagging_freq': 3, 'lambda_l1': 3.381674744626196, 'lambda_l2': 0.12687102775811998, 'reg_alpha': 0.9115487032231381, 'reg_lambda': 0.6447914466638227, 'colsample_bytree': 0.4671383835507896, 'subsample': 1, 'min_child_samples': 13}. Best is trial 6 with value: 0.6067248028396429.
# [I 2025-01-01 08:53:44,343] Trial 7 finished with value: 0.6001461188433258 and parameters: {'n_estimators': 172, 'learning_rate': 0.07010280804062419, 'max_depth': 4, 'num_leaves': 163, 'min_data_in_leaf': 92, 'bagging_fraction': 0.5367483921780871, 'bagging_freq': 1, 'lambda_l1': 0.008606455957206223, 'lambda_l2': 0.01820656386434319, 'reg_alpha': 0.5307144850911691, 'reg_lambda': 0.7624395015378691, 'colsample_bytree': 0.5991628857211335, 'subsample': 0, 'min_child_samples': 24}. Best is trial 6 with value: 0.6067248028396429.
# [I 2025-01-01 08:54:02,182] Trial 8 finished with value: 0.5946629925672882 and parameters: {'n_estimators': 404, 'learning_rate': 0.04190945264257789, 'max_depth': 6, 'num_leaves': 60, 'min_data_in_leaf': 14, 'bagging_fraction': 0.7001090979249307, 'bagging_freq': 1, 'lambda_l1': 3.352133908483968, 'lambda_l2': 7.15786474652691, 'reg_alpha': 0.8583386276463215, 'reg_lambda': 0.6649205328348491, 'colsample_bytree': 0.8530879887010803, 'subsample': 0, 'min_child_samples': 26}. Best is trial 6 with value: 0.6067248028396429.
# [I 2025-01-01 08:54:08,136] Trial 9 finished with value: 0.5986882664567182 and parameters: {'n_estimators': 280, 'learning_rate': 0.025948918234211547, 'max_depth': 5, 'num_leaves': 58, 'min_data_in_leaf': 29, 'bagging_fraction': 0.4662033928409813, 'bagging_freq': 1, 'lambda_l1': 6.944630332856475, 'lambda_l2': 0.014849787374661432, 'reg_alpha': 0.5168709737773252, 'reg_lambda': 0.5482896483466001, 'colsample_bytree': 0.9651044265795405, 'subsample': 1, 'min_child_samples': 18}. Best is trial 6 with value: 0.6067248028396429.
# [I 2025-01-01 08:54:26,861] Trial 10 finished with value: 0.6070951040179347 and parameters: {'n_estimators': 664, 'learning_rate': 0.010047070540243688, 'max_depth': 8, 'num_leaves': 254, 'min_data_in_leaf': 61, 'bagging_fraction': 0.937741787506965, 'bagging_freq': 3, 'lambda_l1': 0.0010523414148403637, 'lambda_l2': 0.3004390870844365, 'reg_alpha': 0.9783099298389379, 'reg_lambda': 0.9750772554998505, 'colsample_bytree': 0.40921788420311955, 'subsample': 1, 'min_child_samples': 10}. Best is trial 10 with value: 0.6070951040179347.
# [I 2025-01-01 08:54:46,052] Trial 11 finished with value: 0.6085562924511936 and parameters: {'n_estimators': 657, 'learning_rate': 0.010189553264408532, 'max_depth': 8, 'num_leaves': 251, 'min_data_in_leaf': 60, 'bagging_fraction': 0.9717516076352771, 'bagging_freq': 3, 'lambda_l1': 0.0016196897105025749, 'lambda_l2': 0.35071332842321407, 'reg_alpha': 0.9958063686840234, 'reg_lambda': 0.9654097020563236, 'colsample_bytree': 0.439539384351995, 'subsample': 1, 'min_child_samples': 11}. Best is trial 11 with value: 0.6085562924511936.
# [I 2025-01-01 08:55:06,552] Trial 12 finished with value: 0.6067281388862942 and parameters: {'n_estimators': 763, 'learning_rate': 0.010582690719636408, 'max_depth': 8, 'num_leaves': 254, 'min_data_in_leaf': 66, 'bagging_fraction': 0.9770009645759693, 'bagging_freq': 4, 'lambda_l1': 0.0010095618115474494, 'lambda_l2': 0.6267767390478195, 'reg_alpha': 0.9970817181746011, 'reg_lambda': 0.9847297297290396, 'colsample_bytree': 0.41280048316822526, 'subsample': 1, 'min_child_samples': 48}. Best is trial 11 with value: 0.6085562924511936.
# [I 2025-01-01 08:55:31,619] Trial 13 finished with value: 0.5972224075581474 and parameters: {'n_estimators': 826, 'learning_rate': 0.016311640876081616, 'max_depth': 8, 'num_leaves': 210, 'min_data_in_leaf': 62, 'bagging_fraction': 0.9978599796069645, 'bagging_freq': 3, 'lambda_l1': 0.0012677434631222315, 'lambda_l2': 3.9576163443756056, 'reg_alpha': 0.998838348496922, 'reg_lambda': 0.9928054143497846, 'colsample_bytree': 0.5612974742249248, 'subsample': 1, 'min_child_samples': 10}. Best is trial 11 with value: 0.6085562924511936.
# [I 2025-01-01 08:55:49,194] Trial 14 finished with value: 0.5994135229987057 and parameters: {'n_estimators': 598, 'learning_rate': 0.018157736926858837, 'max_depth': 8, 'num_leaves': 218, 'min_data_in_leaf': 50, 'bagging_fraction': 0.7898263987329728, 'bagging_freq': 3, 'lambda_l1': 0.004181220343534448, 'lambda_l2': 0.16910491388092014, 'reg_alpha': 0.7360851949328997, 'reg_lambda': 0.9123685170896592, 'colsample_bytree': 0.4833969411174666, 'subsample': 1, 'min_child_samples': 17}. Best is trial 11 with value: 0.6085562924511936.
# [I 2025-01-01 08:56:14,266] Trial 15 finished with value: 0.606730140514285 and parameters: {'n_estimators': 875, 'learning_rate': 0.010226297481090751, 'max_depth': 6, 'num_leaves': 164, 'min_data_in_leaf': 75, 'bagging_fraction': 0.8942093931451206, 'bagging_freq': 4, 'lambda_l1': 0.11805419651390198, 'lambda_l2': 1.09913169776403, 'reg_alpha': 0.6639945445309282, 'reg_lambda': 0.9156214999478001, 'colsample_bytree': 0.6923238518635356, 'subsample': 1, 'min_child_samples': 10}. Best is trial 11 with value: 0.6085562924511936.
# [I 2025-01-01 08:56:36,726] Trial 16 finished with value: 0.6012396749356144 and parameters: {'n_estimators': 717, 'learning_rate': 0.01772204590120794, 'max_depth': 8, 'num_leaves': 228, 'min_data_in_leaf': 36, 'bagging_fraction': 0.8102291869971957, 'bagging_freq': 4, 'lambda_l1': 0.0025064215202081786, 'lambda_l2': 1.7441847492349025, 'reg_alpha': 0.9298480670786855, 'reg_lambda': 0.9332154744427934, 'colsample_bytree': 0.40333969625511695, 'subsample': 1, 'min_child_samples': 41}. Best is trial 11 with value: 0.6085562924511936.
# [I 2025-01-01 08:56:49,295] Trial 17 finished with value: 0.612211265162332 and parameters: {'n_estimators': 503, 'learning_rate': 0.013775590888143298, 'max_depth': 5, 'num_leaves': 183, 'min_data_in_leaf': 61, 'bagging_fraction': 0.9532251155249837, 'bagging_freq': 5, 'lambda_l1': 0.020862159319951553, 'lambda_l2': 0.22882394246136487, 'reg_alpha': 0.8156779243896362, 'reg_lambda': 0.7965919639012158, 'colsample_bytree': 0.5046168692736848, 'subsample': 1, 'min_child_samples': 15}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:57:00,751] Trial 18 finished with value: 0.6081879929008928 and parameters: {'n_estimators': 494, 'learning_rate': 0.014194121791765152, 'max_depth': 5, 'num_leaves': 180, 'min_data_in_leaf': 82, 'bagging_fraction': 0.7940599909608816, 'bagging_freq': 5, 'lambda_l1': 0.01807179399064397, 'lambda_l2': 0.05696403536538354, 'reg_alpha': 0.7978702375150151, 'reg_lambda': 0.7551432515964809, 'colsample_bytree': 0.6513028287795388, 'subsample': 1, 'min_child_samples': 21}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:57:13,058] Trial 19 finished with value: 0.6056272434913729 and parameters: {'n_estimators': 502, 'learning_rate': 0.020073815010455024, 'max_depth': 5, 'num_leaves': 133, 'min_data_in_leaf': 55, 'bagging_fraction': 0.7357211439050345, 'bagging_freq': 5, 'lambda_l1': 0.4548674197678493, 'lambda_l2': 0.002850599803493987, 'reg_alpha': 0.6396828487987398, 'reg_lambda': 0.8211812775565479, 'colsample_bytree': 0.5121177868825444, 'subsample': 1, 'min_child_samples': 15}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:57:38,063] Trial 20 finished with value: 0.604897983693404 and parameters: {'n_estimators': 952, 'learning_rate': 0.013290066600354405, 'max_depth': 5, 'num_leaves': 140, 'min_data_in_leaf': 43, 'bagging_fraction': 0.8391099434881165, 'bagging_freq': 6, 'lambda_l1': 0.055565663828913564, 'lambda_l2': 2.225338678144596, 'reg_alpha': 0.78901583957114, 'reg_lambda': 0.7123832833494471, 'colsample_bytree': 0.5190738069672819, 'subsample': 0, 'min_child_samples': 22}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:57:49,624] Trial 21 finished with value: 0.6089212559548434 and parameters: {'n_estimators': 455, 'learning_rate': 0.01357094722583207, 'max_depth': 5, 'num_leaves': 189, 'min_data_in_leaf': 79, 'bagging_fraction': 0.949195145678621, 'bagging_freq': 5, 'lambda_l1': 0.019822024003818516, 'lambda_l2': 0.06139485787655489, 'reg_alpha': 0.784393846881699, 'reg_lambda': 0.7588163113350787, 'colsample_bytree': 0.6463144025737397, 'subsample': 1, 'min_child_samples': 21}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:58:06,400] Trial 22 finished with value: 0.6085576268698543 and parameters: {'n_estimators': 582, 'learning_rate': 0.012801509777632687, 'max_depth': 6, 'num_leaves': 192, 'min_data_in_leaf': 72, 'bagging_fraction': 0.9371062477509637, 'bagging_freq': 6, 'lambda_l1': 0.013068958918384582, 'lambda_l2': 0.2179261185566631, 'reg_alpha': 0.7002757358158923, 'reg_lambda': 0.8029361486282797, 'colsample_bytree': 0.64162822798226, 'subsample': 1, 'min_child_samples': 15}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:58:20,625] Trial 23 finished with value: 0.6008780474786158 and parameters: {'n_estimators': 456, 'learning_rate': 0.02499206107678508, 'max_depth': 6, 'num_leaves': 195, 'min_data_in_leaf': 80, 'bagging_fraction': 0.9351536995335319, 'bagging_freq': 6, 'lambda_l1': 0.01622977025720939, 'lambda_l2': 0.10695510457048607, 'reg_alpha': 0.6860622587041153, 'reg_lambda': 0.7899371240235973, 'colsample_bytree': 0.7460162802524619, 'subsample': 1, 'min_child_samples': 15}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:58:22,257] Trial 24 finished with value: 0.5899057900425679 and parameters: {'n_estimators': 44, 'learning_rate': 0.02220588211157779, 'max_depth': 5, 'num_leaves': 142, 'min_data_in_leaf': 66, 'bagging_fraction': 0.9385007205818617, 'bagging_freq': 7, 'lambda_l1': 0.0714937112908346, 'lambda_l2': 0.04697455918461893, 'reg_alpha': 0.7725090143988292, 'reg_lambda': 0.7143380208275263, 'colsample_bytree': 0.635988717671626, 'subsample': 1, 'min_child_samples': 21}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:58:38,945] Trial 25 finished with value: 0.6059975446696646 and parameters: {'n_estimators': 580, 'learning_rate': 0.015462226490298443, 'max_depth': 6, 'num_leaves': 177, 'min_data_in_leaf': 71, 'bagging_fraction': 0.8634196448232105, 'bagging_freq': 5, 'lambda_l1': 0.008921042914841953, 'lambda_l2': 0.26213180244518747, 'reg_alpha': 0.705683509172972, 'reg_lambda': 0.8767583343444626, 'colsample_bytree': 0.7077290231753699, 'subsample': 1, 'min_child_samples': 16}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:58:50,774] Trial 26 finished with value: 0.6100141448378014 and parameters: {'n_estimators': 587, 'learning_rate': 0.012594777601625636, 'max_depth': 4, 'num_leaves': 233, 'min_data_in_leaf': 85, 'bagging_fraction': 0.757599091501595, 'bagging_freq': 6, 'lambda_l1': 0.05177359122559294, 'lambda_l2': 0.006067600270193952, 'reg_alpha': 0.6102292369191752, 'reg_lambda': 0.8058259893181943, 'colsample_bytree': 0.6439985022825124, 'subsample': 1, 'min_child_samples': 14}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:58:58,513] Trial 27 finished with value: 0.6074553970562724 and parameters: {'n_estimators': 411, 'learning_rate': 0.012030618964271177, 'max_depth': 4, 'num_leaves': 230, 'min_data_in_leaf': 88, 'bagging_fraction': 0.7329660107654203, 'bagging_freq': 7, 'lambda_l1': 0.03703374889019528, 'lambda_l2': 0.003533744396284402, 'reg_alpha': 0.6125004069742913, 'reg_lambda': 0.7184486919610202, 'colsample_bytree': 0.5396011117950532, 'subsample': 1, 'min_child_samples': 19}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:59:03,190] Trial 28 finished with value: 0.6067281388862942 and parameters: {'n_estimators': 234, 'learning_rate': 0.015463721532299118, 'max_depth': 4, 'num_leaves': 232, 'min_data_in_leaf': 83, 'bagging_fraction': 0.7532315751362021, 'bagging_freq': 5, 'lambda_l1': 0.11411931287533843, 'lambda_l2': 0.0044397727970838545, 'reg_alpha': 0.8462020497997604, 'reg_lambda': 0.8756378816367503, 'colsample_bytree': 0.5987811626046525, 'subsample': 1, 'min_child_samples': 13}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:59:08,210] Trial 29 finished with value: 0.59174061570077 and parameters: {'n_estimators': 353, 'learning_rate': 0.03186302587397209, 'max_depth': 4, 'num_leaves': 209, 'min_data_in_leaf': 86, 'bagging_fraction': 0.4107459766068159, 'bagging_freq': 6, 'lambda_l1': 0.28993798832696394, 'lambda_l2': 0.00903081534156844, 'reg_alpha': 0.871767837915608, 'reg_lambda': 0.7828013502708039, 'colsample_bytree': 0.6960966490014164, 'subsample': 1, 'min_child_samples': 33}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:59:20,441] Trial 30 finished with value: 0.605632581166015 and parameters: {'n_estimators': 451, 'learning_rate': 0.020504990852429274, 'max_depth': 5, 'num_leaves': 158, 'min_data_in_leaf': 77, 'bagging_fraction': 0.8378561666911213, 'bagging_freq': 5, 'lambda_l1': 0.04939977737979003, 'lambda_l2': 0.0010356540132414075, 'reg_alpha': 0.7641416517965123, 'reg_lambda': 0.8496752447701419, 'colsample_bytree': 0.7480780766326117, 'subsample': 1, 'min_child_samples': 30}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:59:37,138] Trial 31 finished with value: 0.6100148120471316 and parameters: {'n_estimators': 596, 'learning_rate': 0.01222251783124123, 'max_depth': 6, 'num_leaves': 192, 'min_data_in_leaf': 71, 'bagging_fraction': 0.9123303440360323, 'bagging_freq': 6, 'lambda_l1': 0.013118742887330746, 'lambda_l2': 0.03238340992815147, 'reg_alpha': 0.602670905149492, 'reg_lambda': 0.8070755395056151, 'colsample_bytree': 0.6414079338988468, 'subsample': 1, 'min_child_samples': 13}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 08:59:51,365] Trial 32 finished with value: 0.6081879929008928 and parameters: {'n_estimators': 571, 'learning_rate': 0.01238827350001102, 'max_depth': 5, 'num_leaves': 180, 'min_data_in_leaf': 73, 'bagging_fraction': 0.9016111026849922, 'bagging_freq': 6, 'lambda_l1': 0.003652949074602007, 'lambda_l2': 0.03029871068839565, 'reg_alpha': 0.6083835431487364, 'reg_lambda': 0.7409481377216617, 'colsample_bytree': 0.5829192573124455, 'subsample': 1, 'min_child_samples': 12}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:00:06,688] Trial 33 finished with value: 0.6049019869493856 and parameters: {'n_estimators': 745, 'learning_rate': 0.011823178187593868, 'max_depth': 4, 'num_leaves': 202, 'min_data_in_leaf': 95, 'bagging_fraction': 0.9925879105967901, 'bagging_freq': 7, 'lambda_l1': 0.025297440529188808, 'lambda_l2': 0.07570287377873998, 'reg_alpha': 0.5749433829165519, 'reg_lambda': 0.8219488594934052, 'colsample_bytree': 0.6460393702066047, 'subsample': 1, 'min_child_samples': 23}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:00:24,029] Trial 34 finished with value: 0.6001494548899772 and parameters: {'n_estimators': 651, 'learning_rate': 0.014881046478349867, 'max_depth': 6, 'num_leaves': 125, 'min_data_in_leaf': 69, 'bagging_fraction': 0.6888033971253663, 'bagging_freq': 5, 'lambda_l1': 0.010834505464648321, 'lambda_l2': 0.008414054177337581, 'reg_alpha': 0.8159274162176329, 'reg_lambda': 0.8651571098388156, 'colsample_bytree': 0.7442861231826354, 'subsample': 1, 'min_child_samples': 19}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:00:33,322] Trial 35 finished with value: 0.6052649488250443 and parameters: {'n_estimators': 547, 'learning_rate': 0.018082044298134967, 'max_depth': 5, 'num_leaves': 237, 'min_data_in_leaf': 98, 'bagging_fraction': 0.5768288962733976, 'bagging_freq': 6, 'lambda_l1': 0.02896015747989005, 'lambda_l2': 0.021398667726138677, 'reg_alpha': 0.5759435360532781, 'reg_lambda': 0.6847560106791228, 'colsample_bytree': 0.6184882615250944, 'subsample': 0, 'min_child_samples': 14}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:00:44,279] Trial 36 finished with value: 0.6114760004803907 and parameters: {'n_estimators': 437, 'learning_rate': 0.011532763385543153, 'max_depth': 4, 'num_leaves': 189, 'min_data_in_leaf': 55, 'bagging_fraction': 0.9542462864035404, 'bagging_freq': 4, 'lambda_l1': 0.20716103677560666, 'lambda_l2': 0.027854407282660764, 'reg_alpha': 0.7368513340408751, 'reg_lambda': 0.7735969903828332, 'colsample_bytree': 0.6760680592084954, 'subsample': 1, 'min_child_samples': 17}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:00:54,681] Trial 37 finished with value: 0.6092862194584929 and parameters: {'n_estimators': 403, 'learning_rate': 0.011778292591801113, 'max_depth': 4, 'num_leaves': 152, 'min_data_in_leaf': 56, 'bagging_fraction': 0.9025740669769156, 'bagging_freq': 4, 'lambda_l1': 0.8064696474771834, 'lambda_l2': 0.029599863632866878, 'reg_alpha': 0.6502611773512503, 'reg_lambda': 0.8287583442492377, 'colsample_bytree': 0.6758910093272096, 'subsample': 1, 'min_child_samples': 17}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:01:09,979] Trial 38 finished with value: 0.5921049119950894 and parameters: {'n_estimators': 703, 'learning_rate': 0.03601916881820252, 'max_depth': 4, 'num_leaves': 219, 'min_data_in_leaf': 41, 'bagging_fraction': 0.8658707657236708, 'bagging_freq': 4, 'lambda_l1': 0.1820492389327163, 'lambda_l2': 0.005870203215592111, 'reg_alpha': 0.600223723703366, 'reg_lambda': 0.8061980453775127, 'colsample_bytree': 0.5597238316536075, 'subsample': 0, 'min_child_samples': 29}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:01:30,957] Trial 39 finished with value: 0.6114786693177118 and parameters: {'n_estimators': 784, 'learning_rate': 0.011299567900737866, 'max_depth': 4, 'num_leaves': 170, 'min_data_in_leaf': 54, 'bagging_fraction': 0.8281004773524893, 'bagging_freq': 2, 'lambda_l1': 0.7045524310770004, 'lambda_l2': 0.002321376359328944, 'reg_alpha': 0.7195617096822184, 'reg_lambda': 0.6072834608993908, 'colsample_bytree': 0.812556058614242, 'subsample': 1, 'min_child_samples': 35}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:01:59,548] Trial 40 finished with value: 0.5851599300764623 and parameters: {'n_estimators': 992, 'learning_rate': 0.049766574897390774, 'max_depth': 7, 'num_leaves': 109, 'min_data_in_leaf': 48, 'bagging_fraction': 0.830109366515141, 'bagging_freq': 2, 'lambda_l1': 1.6043439963012112, 'lambda_l2': 0.0018768781722187636, 'reg_alpha': 0.7429942609370452, 'reg_lambda': 0.5983552472088606, 'colsample_bytree': 0.8780277128368537, 'subsample': 1, 'min_child_samples': 40}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:02:20,423] Trial 41 finished with value: 0.6045336873990846 and parameters: {'n_estimators': 789, 'learning_rate': 0.011186168607237926, 'max_depth': 4, 'num_leaves': 170, 'min_data_in_leaf': 58, 'bagging_fraction': 0.78139858882128, 'bagging_freq': 2, 'lambda_l1': 0.4527106721950521, 'lambda_l2': 0.0021023930904870043, 'reg_alpha': 0.6738226585169975, 'reg_lambda': 0.6090955869107189, 'colsample_bytree': 0.8859519497825571, 'subsample': 1, 'min_child_samples': 38}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:02:39,570] Trial 42 finished with value: 0.6030718317564953 and parameters: {'n_estimators': 863, 'learning_rate': 0.01454183856023767, 'max_depth': 4, 'num_leaves': 186, 'min_data_in_leaf': 65, 'bagging_fraction': 0.6762130895391871, 'bagging_freq': 2, 'lambda_l1': 1.531609437969299, 'lambda_l2': 0.010925973130902936, 'reg_alpha': 0.7093004623240706, 'reg_lambda': 0.7705760593142316, 'colsample_bytree': 0.7899378964320979, 'subsample': 1, 'min_child_samples': 34}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:02:59,194] Trial 43 finished with value: 0.6096465124968307 and parameters: {'n_estimators': 635, 'learning_rate': 0.016584359080872284, 'max_depth': 4, 'num_leaves': 201, 'min_data_in_leaf': 30, 'bagging_fraction': 0.9100863854914579, 'bagging_freq': 6, 'lambda_l1': 0.18506443893917124, 'lambda_l2': 0.005139484695824998, 'reg_alpha': 0.5476235977251831, 'reg_lambda': 0.5009832753408792, 'colsample_bytree': 0.8137724386631562, 'subsample': 1, 'min_child_samples': 36}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:03:13,858] Trial 44 finished with value: 0.6103831115974325 and parameters: {'n_estimators': 521, 'learning_rate': 0.011460165756790385, 'max_depth': 4, 'num_leaves': 26, 'min_data_in_leaf': 45, 'bagging_fraction': 0.9659343392505039, 'bagging_freq': 7, 'lambda_l1': 0.08113305501777189, 'lambda_l2': 0.026542550077948326, 'reg_alpha': 0.636637982705421, 'reg_lambda': 0.6791455933627363, 'colsample_bytree': 0.7233729263633518, 'subsample': 1, 'min_child_samples': 47}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:03:22,115] Trial 45 finished with value: 0.6063585049173328 and parameters: {'n_estimators': 267, 'learning_rate': 0.011073604482056073, 'max_depth': 4, 'num_leaves': 25, 'min_data_in_leaf': 47, 'bagging_fraction': 0.9729946141769101, 'bagging_freq': 7, 'lambda_l1': 0.7011978031468951, 'lambda_l2': 0.03009779054928168, 'reg_alpha': 0.7263157266779806, 'reg_lambda': 0.6783176280194881, 'colsample_bytree': 0.7782583945273677, 'subsample': 1, 'min_child_samples': 43}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:03:33,842] Trial 46 finished with value: 0.5884486048652905 and parameters: {'n_estimators': 347, 'learning_rate': 0.08883528212187838, 'max_depth': 5, 'num_leaves': 97, 'min_data_in_leaf': 53, 'bagging_fraction': 0.9186697065667889, 'bagging_freq': 7, 'lambda_l1': 0.08790919384769212, 'lambda_l2': 0.46996955747199676, 'reg_alpha': 0.6349730586906173, 'reg_lambda': 0.6384724190895288, 'colsample_bytree': 0.848591006025841, 'subsample': 1, 'min_child_samples': 49}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:03:49,819] Trial 47 finished with value: 0.6100154792564618 and parameters: {'n_estimators': 528, 'learning_rate': 0.011129675881313241, 'max_depth': 4, 'num_leaves': 121, 'min_data_in_leaf': 30, 'bagging_fraction': 0.9674200340093425, 'bagging_freq': 1, 'lambda_l1': 0.3026167720858512, 'lambda_l2': 0.13376009379725662, 'reg_alpha': 0.8113939892614479, 'reg_lambda': 0.6104903266880372, 'colsample_bytree': 0.7278146620965109, 'subsample': 0, 'min_child_samples': 43}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:04:09,297] Trial 48 finished with value: 0.6059928742043528 and parameters: {'n_estimators': 498, 'learning_rate': 0.010021044429263035, 'max_depth': 4, 'num_leaves': 117, 'min_data_in_leaf': 22, 'bagging_fraction': 0.9600112499228929, 'bagging_freq': 1, 'lambda_l1': 0.32696892138632716, 'lambda_l2': 0.14636488571912917, 'reg_alpha': 0.8229091808543358, 'reg_lambda': 0.5559533172284081, 'colsample_bytree': 0.9229089125984393, 'subsample': 0, 'min_child_samples': 46}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:04:25,321] Trial 49 finished with value: 0.6063551688706814 and parameters: {'n_estimators': 529, 'learning_rate': 0.011197045993153585, 'max_depth': 4, 'num_leaves': 79, 'min_data_in_leaf': 21, 'bagging_fraction': 0.877195538865696, 'bagging_freq': 2, 'lambda_l1': 0.17135995693557726, 'lambda_l2': 0.09001212502562453, 'reg_alpha': 0.8994724335198391, 'reg_lambda': 0.5825652223762352, 'colsample_bytree': 0.719519353937982, 'subsample': 0, 'min_child_samples': 45}. Best is trial 17 with value: 0.612211265162332.
# [I 2025-01-01 09:04:37,229] Trial 50 finished with value: 0.6125735598286607 and parameters: {'n_estimators': 397, 'learning_rate': 0.013863280433522925, 'max_depth': 4, 'num_leaves': 29, 'min_data_in_leaf': 32, 'bagging_fraction': 0.9978125319607524, 'bagging_freq': 1, 'lambda_l1': 2.61253889839802, 'lambda_l2': 0.9989587388919079, 'reg_alpha': 0.7617057719664783, 'reg_lambda': 0.6256149135623483, 'colsample_bytree': 0.8153880904742704, 'subsample': 0, 'min_child_samples': 46}. Best is trial 50 with value: 0.6125735598286607.
# [I 2025-01-01 09:04:48,408] Trial 51 finished with value: 0.6129371889136498 and parameters: {'n_estimators': 384, 'learning_rate': 0.013704073947528985, 'max_depth': 4, 'num_leaves': 28, 'min_data_in_leaf': 32, 'bagging_fraction': 0.9938339647580327, 'bagging_freq': 1, 'lambda_l1': 2.9220866202772635, 'lambda_l2': 0.9021152457611539, 'reg_alpha': 0.7585354724077407, 'reg_lambda': 0.6225378775877084, 'colsample_bytree': 0.7722905521044361, 'subsample': 0, 'min_child_samples': 47}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:04:55,331] Trial 52 finished with value: 0.6111123713954016 and parameters: {'n_estimators': 306, 'learning_rate': 0.013805808605796263, 'max_depth': 4, 'num_leaves': 18, 'min_data_in_leaf': 35, 'bagging_fraction': 0.9970130977084387, 'bagging_freq': 1, 'lambda_l1': 9.500329962163498, 'lambda_l2': 1.1427914146503901, 'reg_alpha': 0.7434427659068608, 'reg_lambda': 0.6276974603476704, 'colsample_bytree': 0.7705226364654765, 'subsample': 0, 'min_child_samples': 50}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:05:02,441] Trial 53 finished with value: 0.607091100761953 and parameters: {'n_estimators': 314, 'learning_rate': 0.013618189308093524, 'max_depth': 4, 'num_leaves': 43, 'min_data_in_leaf': 39, 'bagging_fraction': 0.9990938935156296, 'bagging_freq': 1, 'lambda_l1': 9.135810452035026, 'lambda_l2': 1.0234247487905743, 'reg_alpha': 0.7561217026840428, 'reg_lambda': 0.5368875327528734, 'colsample_bytree': 0.8144089128809486, 'subsample': 0, 'min_child_samples': 50}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:05:09,364] Trial 54 finished with value: 0.6096485141248216 and parameters: {'n_estimators': 203, 'learning_rate': 0.0164671225804474, 'max_depth': 5, 'num_leaves': 18, 'min_data_in_leaf': 36, 'bagging_fraction': 0.9864024493426278, 'bagging_freq': 1, 'lambda_l1': 3.0724746117527717, 'lambda_l2': 0.9091347560295003, 'reg_alpha': 0.7446581910558503, 'reg_lambda': 0.5745459349583661, 'colsample_bytree': 0.7720147059086014, 'subsample': 0, 'min_child_samples': 44}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:05:21,034] Trial 55 finished with value: 0.604535021817745 and parameters: {'n_estimators': 403, 'learning_rate': 0.019881021036760954, 'max_depth': 4, 'num_leaves': 34, 'min_data_in_leaf': 24, 'bagging_fraction': 0.9991805844114434, 'bagging_freq': 1, 'lambda_l1': 4.8672068516252684, 'lambda_l2': 2.0443491338307203, 'reg_alpha': 0.7220911185040457, 'reg_lambda': 0.6524106603337554, 'colsample_bytree': 0.835081048692937, 'subsample': 0, 'min_child_samples': 48}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:05:33,047] Trial 56 finished with value: 0.6125735598286607 and parameters: {'n_estimators': 320, 'learning_rate': 0.013884249340194178, 'max_depth': 4, 'num_leaves': 71, 'min_data_in_leaf': 13, 'bagging_fraction': 0.9492688330390426, 'bagging_freq': 2, 'lambda_l1': 2.367751129776578, 'lambda_l2': 6.639014923901993, 'reg_alpha': 0.7825441180819874, 'reg_lambda': 0.6324546881553273, 'colsample_bytree': 0.8714355873718198, 'subsample': 0, 'min_child_samples': 50}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:05:55,006] Trial 57 finished with value: 0.5928348390023885 and parameters: {'n_estimators': 375, 'learning_rate': 0.0281011626776673, 'max_depth': 5, 'num_leaves': 69, 'min_data_in_leaf': 5, 'bagging_fraction': 0.9477785032755663, 'bagging_freq': 2, 'lambda_l1': 2.386367507473379, 'lambda_l2': 8.040396306798591, 'reg_alpha': 0.7789133477451675, 'reg_lambda': 0.7421419074645703, 'colsample_bytree': 0.8862937975839755, 'subsample': 0, 'min_child_samples': 25}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:06:11,394] Trial 58 finished with value: 0.5913723161504691 and parameters: {'n_estimators': 439, 'learning_rate': 0.05399778954086783, 'max_depth': 4, 'num_leaves': 55, 'min_data_in_leaf': 12, 'bagging_fraction': 0.9261656762819398, 'bagging_freq': 3, 'lambda_l1': 1.0201998531188992, 'lambda_l2': 4.561955644285183, 'reg_alpha': 0.8012906411426237, 'reg_lambda': 0.6653291353577007, 'colsample_bytree': 0.9255610618220321, 'subsample': 0, 'min_child_samples': 41}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:06:17,613] Trial 59 finished with value: 0.607091100761953 and parameters: {'n_estimators': 130, 'learning_rate': 0.017459587942965725, 'max_depth': 5, 'num_leaves': 87, 'min_data_in_leaf': 19, 'bagging_fraction': 0.8813842450043612, 'bagging_freq': 2, 'lambda_l1': 5.103762103302893, 'lambda_l2': 3.3628933998488844, 'reg_alpha': 0.837337269990475, 'reg_lambda': 0.5855938648306128, 'colsample_bytree': 0.9879724054985508, 'subsample': 0, 'min_child_samples': 28}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:06:28,891] Trial 60 finished with value: 0.6052616127783932 and parameters: {'n_estimators': 332, 'learning_rate': 0.02302747900918044, 'max_depth': 4, 'num_leaves': 65, 'min_data_in_leaf': 16, 'bagging_fraction': 0.9541380945208792, 'bagging_freq': 3, 'lambda_l1': 2.0336741776351976, 'lambda_l2': 0.44196834431703186, 'reg_alpha': 0.8692761974116603, 'reg_lambda': 0.6935133588490069, 'colsample_bytree': 0.8613926250217101, 'subsample': 0, 'min_child_samples': 47}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:06:36,149] Trial 61 finished with value: 0.6074560642656028 and parameters: {'n_estimators': 267, 'learning_rate': 0.013640535979303897, 'max_depth': 4, 'num_leaves': 36, 'min_data_in_leaf': 34, 'bagging_fraction': 0.9529192462411706, 'bagging_freq': 1, 'lambda_l1': 6.031695607433164, 'lambda_l2': 1.4133849606686446, 'reg_alpha': 0.7610368521196895, 'reg_lambda': 0.6293000081759131, 'colsample_bytree': 0.8095918593824286, 'subsample': 0, 'min_child_samples': 49}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:06:44,117] Trial 62 finished with value: 0.6085536236138726 and parameters: {'n_estimators': 310, 'learning_rate': 0.014593517414405198, 'max_depth': 4, 'num_leaves': 16, 'min_data_in_leaf': 10, 'bagging_fraction': 0.9777256464070141, 'bagging_freq': 1, 'lambda_l1': 9.55406902835349, 'lambda_l2': 2.830422777501832, 'reg_alpha': 0.724738838094992, 'reg_lambda': 0.6192860707950817, 'colsample_bytree': 0.767361791051625, 'subsample': 0, 'min_child_samples': 50}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:06:56,430] Trial 63 finished with value: 0.6107487423104125 and parameters: {'n_estimators': 390, 'learning_rate': 0.013077884242567245, 'max_depth': 4, 'num_leaves': 45, 'min_data_in_leaf': 27, 'bagging_fraction': 0.9236597902364676, 'bagging_freq': 2, 'lambda_l1': 3.556195274724109, 'lambda_l2': 5.314836243616787, 'reg_alpha': 0.6936193083699136, 'reg_lambda': 0.6526530966461149, 'colsample_bytree': 0.8311069538814468, 'subsample': 0, 'min_child_samples': 45}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:07:01,048] Trial 64 finished with value: 0.6081846568542415 and parameters: {'n_estimators': 236, 'learning_rate': 0.015872789224012987, 'max_depth': 4, 'num_leaves': 30, 'min_data_in_leaf': 50, 'bagging_fraction': 0.8541369893426278, 'bagging_freq': 1, 'lambda_l1': 0.5691665526844053, 'lambda_l2': 0.6794047927199457, 'reg_alpha': 0.7940475162256686, 'reg_lambda': 0.6303030602045366, 'colsample_bytree': 0.4631348574613927, 'subsample': 0, 'min_child_samples': 47}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:07:12,399] Trial 65 finished with value: 0.6089205887455131 and parameters: {'n_estimators': 437, 'learning_rate': 0.01401399429725679, 'max_depth': 4, 'num_leaves': 40, 'min_data_in_leaf': 63, 'bagging_fraction': 0.9757609155124738, 'bagging_freq': 3, 'lambda_l1': 1.484670435818424, 'lambda_l2': 0.22149389852597962, 'reg_alpha': 0.7725534282583248, 'reg_lambda': 0.5956335061626222, 'colsample_bytree': 0.7958568711245078, 'subsample': 0, 'min_child_samples': 50}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:07:30,862] Trial 66 finished with value: 0.6114780021083815 and parameters: {'n_estimators': 477, 'learning_rate': 0.012760637023272951, 'max_depth': 5, 'num_leaves': 49, 'min_data_in_leaf': 33, 'bagging_fraction': 0.9357563048358567, 'bagging_freq': 1, 'lambda_l1': 2.6318443529962052, 'lambda_l2': 1.3225052620312419, 'reg_alpha': 0.7445118441883428, 'reg_lambda': 0.5566353760800253, 'colsample_bytree': 0.9272029370152074, 'subsample': 0, 'min_child_samples': 38}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:07:43,649] Trial 67 finished with value: 0.6107427374264403 and parameters: {'n_estimators': 374, 'learning_rate': 0.010473841420576988, 'max_depth': 5, 'num_leaves': 55, 'min_data_in_leaf': 52, 'bagging_fraction': 0.8825626003016546, 'bagging_freq': 2, 'lambda_l1': 1.037328605200132, 'lambda_l2': 0.7317487184264206, 'reg_alpha': 0.6783452372888844, 'reg_lambda': 0.5520308996348136, 'colsample_bytree': 0.9224978983210561, 'subsample': 0, 'min_child_samples': 36}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:08:01,810] Trial 68 finished with value: 0.6100161464657923 and parameters: {'n_estimators': 468, 'learning_rate': 0.019067546662353187, 'max_depth': 5, 'num_leaves': 148, 'min_data_in_leaf': 32, 'bagging_fraction': 0.9387976862551832, 'bagging_freq': 1, 'lambda_l1': 2.1592967587046026, 'lambda_l2': 0.3679947172849664, 'reg_alpha': 0.7146903841175305, 'reg_lambda': 0.5189624563806142, 'colsample_bytree': 0.9443335326375183, 'subsample': 0, 'min_child_samples': 39}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:08:17,787] Trial 69 finished with value: 0.6059948758323437 and parameters: {'n_estimators': 470, 'learning_rate': 0.012686432222528573, 'max_depth': 7, 'num_leaves': 172, 'min_data_in_leaf': 59, 'bagging_fraction': 0.8912710646027178, 'bagging_freq': 4, 'lambda_l1': 2.8325537619253907, 'lambda_l2': 6.07527123736352, 'reg_alpha': 0.7553086652895842, 'reg_lambda': 0.5724072423066605, 'colsample_bytree': 0.9046321120179657, 'subsample': 0, 'min_child_samples': 34}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:08:30,762] Trial 70 finished with value: 0.605629912328694 and parameters: {'n_estimators': 420, 'learning_rate': 0.015307728979254264, 'max_depth': 5, 'num_leaves': 75, 'min_data_in_leaf': 43, 'bagging_fraction': 0.8250267753907773, 'bagging_freq': 2, 'lambda_l1': 4.136344053126854, 'lambda_l2': 9.538471704858075, 'reg_alpha': 0.7335744386333404, 'reg_lambda': 0.5363415252746124, 'colsample_bytree': 0.8571970182673618, 'subsample': 0, 'min_child_samples': 41}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:08:38,385] Trial 71 finished with value: 0.6096485141248216 and parameters: {'n_estimators': 300, 'learning_rate': 0.013106922991220188, 'max_depth': 4, 'num_leaves': 49, 'min_data_in_leaf': 38, 'bagging_fraction': 0.9855894494527646, 'bagging_freq': 1, 'lambda_l1': 6.689977138498471, 'lambda_l2': 1.3910331672745704, 'reg_alpha': 0.7832751218425382, 'reg_lambda': 0.7290721901727506, 'colsample_bytree': 0.7551282397150326, 'subsample': 0, 'min_child_samples': 32}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:08:53,086] Trial 72 finished with value: 0.6100154792564619 and parameters: {'n_estimators': 481, 'learning_rate': 0.017164661199082363, 'max_depth': 4, 'num_leaves': 27, 'min_data_in_leaf': 26, 'bagging_fraction': 0.956344803013094, 'bagging_freq': 1, 'lambda_l1': 1.8481285840810266, 'lambda_l2': 1.40492532156928, 'reg_alpha': 0.8075485786588091, 'reg_lambda': 0.5974525442673556, 'colsample_bytree': 0.8325952394227797, 'subsample': 0, 'min_child_samples': 43}. Best is trial 51 with value: 0.6129371889136498.
# [I 2025-01-01 09:09:04,306] Trial 73 finished with value: 0.6136691175489398 and parameters: {'n_estimators': 343, 'learning_rate': 0.012108041494671118, 'max_depth': 4, 'num_leaves': 36, 'min_data_in_leaf': 16, 'bagging_fraction': 0.9299772478781354, 'bagging_freq': 1, 'lambda_l1': 1.2325847910008532, 'lambda_l2': 2.194887995345597, 'reg_alpha': 0.7376313058125631, 'reg_lambda': 0.7787902390070068, 'colsample_bytree': 0.6689222061598236, 'subsample': 0, 'min_child_samples': 48}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:09:15,238] Trial 74 finished with value: 0.6122072619063504 and parameters: {'n_estimators': 350, 'learning_rate': 0.010671972044653198, 'max_depth': 4, 'num_leaves': 64, 'min_data_in_leaf': 16, 'bagging_fraction': 0.9217893673746632, 'bagging_freq': 1, 'lambda_l1': 1.1057025458328675, 'lambda_l2': 3.0794876916414378, 'reg_alpha': 0.7678841469233834, 'reg_lambda': 0.7636814323760576, 'colsample_bytree': 0.6752477250580708, 'subsample': 0, 'min_child_samples': 48}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:09:33,032] Trial 75 finished with value: 0.608185991272902 and parameters: {'n_estimators': 373, 'learning_rate': 0.010904104717809046, 'max_depth': 6, 'num_leaves': 63, 'min_data_in_leaf': 16, 'bagging_fraction': 0.9219612193611492, 'bagging_freq': 1, 'lambda_l1': 1.2606152342688703, 'lambda_l2': 2.4006381359299174, 'reg_alpha': 0.8316796993955553, 'reg_lambda': 0.6966554528635569, 'colsample_bytree': 0.6726420568521092, 'subsample': 0, 'min_child_samples': 48}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:09:46,791] Trial 76 finished with value: 0.6122092635343412 and parameters: {'n_estimators': 342, 'learning_rate': 0.012236847192043699, 'max_depth': 4, 'num_leaves': 36, 'min_data_in_leaf': 9, 'bagging_fraction': 0.8493377583763192, 'bagging_freq': 1, 'lambda_l1': 2.830559068591468, 'lambda_l2': 1.802698078438359, 'reg_alpha': 0.7686646065328538, 'reg_lambda': 0.7524442514986796, 'colsample_bytree': 0.9634887824295852, 'subsample': 0, 'min_child_samples': 46}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:09:56,865] Trial 77 finished with value: 0.6136691175489398 and parameters: {'n_estimators': 228, 'learning_rate': 0.012050144384576819, 'max_depth': 4, 'num_leaves': 37, 'min_data_in_leaf': 10, 'bagging_fraction': 0.8552576097450019, 'bagging_freq': 1, 'lambda_l1': 0.8533098350255959, 'lambda_l2': 3.4683022462177773, 'reg_alpha': 0.8513525438673184, 'reg_lambda': 0.7879628942563078, 'colsample_bytree': 0.9782629424918108, 'subsample': 0, 'min_child_samples': 45}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:10:03,084] Trial 78 finished with value: 0.5986815943634156 and parameters: {'n_estimators': 134, 'learning_rate': 0.011915211184558436, 'max_depth': 4, 'num_leaves': 36, 'min_data_in_leaf': 11, 'bagging_fraction': 0.8051688716255823, 'bagging_freq': 1, 'lambda_l1': 1.252052312083317, 'lambda_l2': 3.741952804810468, 'reg_alpha': 0.8477576507595057, 'reg_lambda': 0.7959175900296958, 'colsample_bytree': 0.9794250947391376, 'subsample': 0, 'min_child_samples': 46}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:10:12,593] Trial 79 finished with value: 0.6070897663432925 and parameters: {'n_estimators': 225, 'learning_rate': 0.01049624346461374, 'max_depth': 4, 'num_leaves': 57, 'min_data_in_leaf': 8, 'bagging_fraction': 0.853718264770678, 'bagging_freq': 1, 'lambda_l1': 3.8693480673280924, 'lambda_l2': 2.729147354618188, 'reg_alpha': 0.9102140075815007, 'reg_lambda': 0.7779241120522467, 'colsample_bytree': 0.9602968094021318, 'subsample': 0, 'min_child_samples': 45}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:10:20,416] Trial 80 finished with value: 0.6052602783597326 and parameters: {'n_estimators': 187, 'learning_rate': 0.015027285904923332, 'max_depth': 4, 'num_leaves': 85, 'min_data_in_leaf': 17, 'bagging_fraction': 0.8934346935280508, 'bagging_freq': 1, 'lambda_l1': 0.8149205047743786, 'lambda_l2': 1.8419733417098847, 'reg_alpha': 0.8771195683139057, 'reg_lambda': 0.8423198124890143, 'colsample_bytree': 0.9972833590560926, 'subsample': 0, 'min_child_samples': 46}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:10:35,381] Trial 81 finished with value: 0.6059955430416738 and parameters: {'n_estimators': 333, 'learning_rate': 0.012026929257024433, 'max_depth': 4, 'num_leaves': 40, 'min_data_in_leaf': 7, 'bagging_fraction': 0.8452210971746138, 'bagging_freq': 2, 'lambda_l1': 0.4613421447636321, 'lambda_l2': 4.720071169453606, 'reg_alpha': 0.7667198711565734, 'reg_lambda': 0.7577431186274791, 'colsample_bytree': 0.9730677276195516, 'subsample': 0, 'min_child_samples': 48}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:10:45,169] Trial 82 finished with value: 0.6103777739227905 and parameters: {'n_estimators': 270, 'learning_rate': 0.014257958871437973, 'max_depth': 4, 'num_leaves': 23, 'min_data_in_leaf': 14, 'bagging_fraction': 0.9114671785238364, 'bagging_freq': 1, 'lambda_l1': 0.8785081474461532, 'lambda_l2': 3.053246724153081, 'reg_alpha': 0.7822925265744803, 'reg_lambda': 0.7265821783354871, 'colsample_bytree': 0.794330295365073, 'subsample': 0, 'min_child_samples': 42}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:10:54,994] Trial 83 finished with value: 0.6100121432098107 and parameters: {'n_estimators': 342, 'learning_rate': 0.010111680121648831, 'max_depth': 4, 'num_leaves': 31, 'min_data_in_leaf': 13, 'bagging_fraction': 0.7825712216568979, 'bagging_freq': 2, 'lambda_l1': 0.6645453501662533, 'lambda_l2': 1.771385244762129, 'reg_alpha': 0.797072634712072, 'reg_lambda': 0.7622729418335985, 'colsample_bytree': 0.6155943626039432, 'subsample': 0, 'min_child_samples': 44}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:11:05,292] Trial 84 finished with value: 0.6078210277692523 and parameters: {'n_estimators': 241, 'learning_rate': 0.01204721094007909, 'max_depth': 4, 'num_leaves': 71, 'min_data_in_leaf': 9, 'bagging_fraction': 0.8613179117712259, 'bagging_freq': 1, 'lambda_l1': 1.6811708140211814, 'lambda_l2': 6.731314002201256, 'reg_alpha': 0.8235092667190984, 'reg_lambda': 0.788536459472859, 'colsample_bytree': 0.9476514103613689, 'subsample': 0, 'min_child_samples': 49}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:11:15,030] Trial 85 finished with value: 0.6085509547765515 and parameters: {'n_estimators': 292, 'learning_rate': 0.010905412905527396, 'max_depth': 4, 'num_leaves': 52, 'min_data_in_leaf': 5, 'bagging_fraction': 0.8136161968352816, 'bagging_freq': 2, 'lambda_l1': 1.3268788123352369, 'lambda_l2': 0.5434717188861933, 'reg_alpha': 0.9386993646487463, 'reg_lambda': 0.7405462311581098, 'colsample_bytree': 0.49835617409993765, 'subsample': 0, 'min_child_samples': 47}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:11:17,743] Trial 86 finished with value: 0.5888155699969309 and parameters: {'n_estimators': 110, 'learning_rate': 0.012627532436206363, 'max_depth': 4, 'num_leaves': 41, 'min_data_in_leaf': 22, 'bagging_fraction': 0.9390526543494937, 'bagging_freq': 1, 'lambda_l1': 2.309915348404247, 'lambda_l2': 0.8597329608772776, 'reg_alpha': 0.5004046518470597, 'reg_lambda': 0.8247161345482192, 'colsample_bytree': 0.4269514724774741, 'subsample': 0, 'min_child_samples': 48}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:11:22,997] Trial 87 finished with value: 0.6125722254100001 and parameters: {'n_estimators': 169, 'learning_rate': 0.013609484151906782, 'max_depth': 4, 'num_leaves': 23, 'min_data_in_leaf': 19, 'bagging_fraction': 0.600174088955621, 'bagging_freq': 1, 'lambda_l1': 1.0451609621735025, 'lambda_l2': 2.262828520618794, 'reg_alpha': 0.7699274785725764, 'reg_lambda': 0.7071059740211003, 'colsample_bytree': 0.9029575827995427, 'subsample': 0, 'min_child_samples': 44}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:11:27,816] Trial 88 finished with value: 0.6103804427601116 and parameters: {'n_estimators': 162, 'learning_rate': 0.01654098282632806, 'max_depth': 4, 'num_leaves': 23, 'min_data_in_leaf': 19, 'bagging_fraction': 0.6091597212649321, 'bagging_freq': 1, 'lambda_l1': 3.02431868655897, 'lambda_l2': 2.346491751911381, 'reg_alpha': 0.773529906743472, 'reg_lambda': 0.8120437398730521, 'colsample_bytree': 0.9029618568142553, 'subsample': 0, 'min_child_samples': 44}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:11:30,265] Trial 89 finished with value: 0.5921022431577684 and parameters: {'n_estimators': 80, 'learning_rate': 0.015529668008745974, 'max_depth': 4, 'num_leaves': 31, 'min_data_in_leaf': 18, 'bagging_fraction': 0.5271570203348265, 'bagging_freq': 1, 'lambda_l1': 1.9397174701972077, 'lambda_l2': 3.7794282277091895, 'reg_alpha': 0.858377468185429, 'reg_lambda': 0.7089086344256239, 'colsample_bytree': 0.8729943626432883, 'subsample': 0, 'min_child_samples': 46}. Best is trial 73 with value: 0.6136691175489398.
# [I 2025-01-01 09:11:37,871] Trial 90 finished with value: 0.6162312013771201 and parameters: {'n_estimators': 256, 'learning_rate': 0.013579256659883413, 'max_depth': 4, 'num_leaves': 61, 'min_data_in_leaf': 15, 'bagging_fraction': 0.4724962272858123, 'bagging_freq': 1, 'lambda_l1': 0.5610890263591135, 'lambda_l2': 5.471842497266317, 'reg_alpha': 0.8138178726121249, 'reg_lambda': 0.7707264717911311, 'colsample_bytree': 0.9024157827642343, 'subsample': 0, 'min_child_samples': 45}. Best is trial 90 with value: 0.6162312013771201.
# [I 2025-01-01 09:11:46,742] Trial 91 finished with value: 0.6122125995809925 and parameters: {'n_estimators': 254, 'learning_rate': 0.013357834053309576, 'max_depth': 4, 'num_leaves': 59, 'min_data_in_leaf': 15, 'bagging_fraction': 0.5962918121309798, 'bagging_freq': 1, 'lambda_l1': 1.017296839174924, 'lambda_l2': 5.566030225913061, 'reg_alpha': 0.8195440442444568, 'reg_lambda': 0.7535105827560084, 'colsample_bytree': 0.8982765298717847, 'subsample': 0, 'min_child_samples': 45}. Best is trial 90 with value: 0.6162312013771201.
# [I 2025-01-01 09:11:52,946] Trial 92 finished with value: 0.6129411921696313 and parameters: {'n_estimators': 212, 'learning_rate': 0.014220877378124493, 'max_depth': 4, 'num_leaves': 45, 'min_data_in_leaf': 14, 'bagging_fraction': 0.4698738274916142, 'bagging_freq': 1, 'lambda_l1': 0.39407437589611805, 'lambda_l2': 9.638810235114121, 'reg_alpha': 0.8159761170235355, 'reg_lambda': 0.7832290105817497, 'colsample_bytree': 0.9027042087459668, 'subsample': 0, 'min_child_samples': 42}. Best is trial 90 with value: 0.6162312013771201.
# [I 2025-01-01 09:11:58,925] Trial 93 finished with value: 0.6081893273195533 and parameters: {'n_estimators': 200, 'learning_rate': 0.013508693012941783, 'max_depth': 4, 'num_leaves': 48, 'min_data_in_leaf': 14, 'bagging_fraction': 0.483763830953555, 'bagging_freq': 1, 'lambda_l1': 0.593478044111726, 'lambda_l2': 9.202621935189331, 'reg_alpha': 0.8418533521880618, 'reg_lambda': 0.7948302700827009, 'colsample_bytree': 0.9012824404063715, 'subsample': 0, 'min_child_samples': 42}. Best is trial 90 with value: 0.6162312013771201.
# [I 2025-01-01 09:12:04,091] Trial 94 finished with value: 0.609649848543482 and parameters: {'n_estimators': 218, 'learning_rate': 0.014473501315018662, 'max_depth': 4, 'num_leaves': 60, 'min_data_in_leaf': 25, 'bagging_fraction': 0.4320086197430103, 'bagging_freq': 1, 'lambda_l1': 0.005820453603154002, 'lambda_l2': 5.431601099888392, 'reg_alpha': 0.8189679249314181, 'reg_lambda': 0.7850850966934951, 'colsample_bytree': 0.8443882662083825, 'subsample': 0, 'min_child_samples': 45}. Best is trial 90 with value: 0.6162312013771201.
# [I 2025-01-01 09:12:09,502] Trial 95 finished with value: 0.6100148120471317 and parameters: {'n_estimators': 171, 'learning_rate': 0.01600158261212115, 'max_depth': 4, 'num_leaves': 22, 'min_data_in_leaf': 20, 'bagging_fraction': 0.5680444511084475, 'bagging_freq': 1, 'lambda_l1': 0.387068292062368, 'lambda_l2': 7.475936598157972, 'reg_alpha': 0.8898149983255312, 'reg_lambda': 0.6652239016249883, 'colsample_bytree': 0.9378760048108636, 'subsample': 0, 'min_child_samples': 42}. Best is trial 90 with value: 0.6162312013771201.
# [I 2025-01-01 09:12:18,310] Trial 96 finished with value: 0.6111110369767411 and parameters: {'n_estimators': 262, 'learning_rate': 0.018980632204640416, 'max_depth': 4, 'num_leaves': 44, 'min_data_in_leaf': 12, 'bagging_fraction': 0.4866701816633792, 'bagging_freq': 1, 'lambda_l1': 0.486317224076393, 'lambda_l2': 4.730014896398453, 'reg_alpha': 0.8545472238536044, 'reg_lambda': 0.7712686332982568, 'colsample_bytree': 0.8926843227539596, 'subsample': 0, 'min_child_samples': 44}. Best is trial 90 with value: 0.6162312013771201.
# [I 2025-01-01 09:12:22,183] Trial 97 finished with value: 0.6063605065453235 and parameters: {'n_estimators': 154, 'learning_rate': 0.013216411656222263, 'max_depth': 4, 'num_leaves': 53, 'min_data_in_leaf': 23, 'bagging_fraction': 0.4474896579456351, 'bagging_freq': 1, 'lambda_l1': 0.9335162663575302, 'lambda_l2': 7.267588911103665, 'reg_alpha': 0.7986523358365978, 'reg_lambda': 0.8158252573104573, 'colsample_bytree': 0.8721471012071621, 'subsample': 0, 'min_child_samples': 49}. Best is trial 90 with value: 0.6162312013771201.
# [I 2025-01-01 09:12:29,670] Trial 98 finished with value: 0.6103811099694418 and parameters: {'n_estimators': 246, 'learning_rate': 0.01480803468452588, 'max_depth': 4, 'num_leaves': 30, 'min_data_in_leaf': 14, 'bagging_fraction': 0.510937834922381, 'bagging_freq': 1, 'lambda_l1': 1.3644689488856763, 'lambda_l2': 4.131901528185357, 'reg_alpha': 0.8123768336899229, 'reg_lambda': 0.8325025602045815, 'colsample_bytree': 0.9144790825983256, 'subsample': 0, 'min_child_samples': 43}. Best is trial 90 with value: 0.6162312013771201.
# [I 2025-01-01 09:12:37,916] Trial 99 finished with value: 0.6114813381550327 and parameters: {'n_estimators': 286, 'learning_rate': 0.014026474155491698, 'max_depth': 4, 'num_leaves': 79, 'min_data_in_leaf': 27, 'bagging_fraction': 0.6546883603260951, 'bagging_freq': 2, 'lambda_l1': 0.22907762402946208, 'lambda_l2': 5.555511937031094, 'reg_alpha': 0.7888492862799459, 'reg_lambda': 0.8552784306799194, 'colsample_bytree': 0.8614915547990113, 'subsample': 0, 'min_child_samples': 47}. Best is trial 90 with value: 0.6162312013771201.
# {'n_estimators': 256,
#  'learning_rate': 0.013579256659883413,
#  'max_depth': 4,
#  'num_leaves': 61,
#  'min_data_in_leaf': 15,
#  'bagging_fraction': 0.4724962272858123,
#  'bagging_freq': 1,
#  'lambda_l1': 0.5610890263591135,
#  'lambda_l2': 5.471842497266317,
#  'reg_alpha': 0.8138178726121249,
#  'reg_lambda': 0.7707264717911311,
#  'colsample_bytree': 0.9024157827642343,
#  'subsample': 0,
#  'min_child_samples': 45}

# %% [markdown]
# # Model training

# %%
def metric(y_true,y_pred):
    N=int(np.max(y_true)+1)
    O=np.zeros((N,N))
    for i in range(len(y_true)):
        O[y_true[i]][y_pred[i]]+=1
    W=np.zeros((N,N))
    for i in range(N):
        for j in range(N):
            W[i][j]=(i-j)**2/(N-1)**2
    #E
    true_count=np.zeros(N)
    pred_count=np.zeros(N)
    for i in range(len(y_true)):
        true_count[y_true[i]]+=1
        pred_count[y_pred[i]]+=1
    
    E=np.zeros((N,N))
    for i in range(len(true_count)):
        for j in range(len(pred_count)):
            E[i][j]=true_count[i]*pred_count[j]
            
    O=O/O.sum()
    E=E/E.sum()
    
    weighted_kappa=1-np.sum(W*O)/np.sum(W*E)
    
    return weighted_kappa

choose_cols=[col for col in test.columns if train[col].dtype!=object]
print(f"len(choose_cols):{len(choose_cols)}")

def fit_and_predict(train_feats=train,test_feats=test,model=None,num_folds=10,name='lgb'):
    X=train_feats[choose_cols].copy()
    y=train_feats[Config.TARGET_NAME].copy()
    oof_pred=np.zeros((len(X)))
    test_X=test_feats[choose_cols].copy()
    test_pred_pro=np.zeros((num_folds,len(test_X)))
    
    skf = StratifiedKFold(n_splits=num_folds,shuffle=True,random_state=Config.seed)
    for fold, (train_index, valid_index) in (enumerate(skf.split(X,y))):
        print(f"name {name},fold:{fold}")

        X_train, X_valid = X.iloc[train_index].reset_index(drop=True), X.iloc[valid_index].reset_index(drop=True)
        y_train, y_valid = y.iloc[train_index].reset_index(drop=True), y.iloc[valid_index].reset_index(drop=True)
        
        y_train=(y_train!=0).astype(np.int8)
        y_valid=(y_valid!=0).astype(np.int8)
        
        model.fit(X_train,y_train,eval_set=[(X_valid, y_valid)],
                          callbacks=[log_evaluation(100)],
                         )
        
        oof_pred[valid_index]=model.predict_proba(X_valid)[:,1]
        test_pred_pro[fold]=model.predict_proba(test_X)[:,1]
        
        importances=model.feature_importances_
        columns=X.columns
        drop_cols=[]
        for i in range(len(columns)):
            if importances[i]<10:
                drop_cols.append(columns[i])
        print(f"drop_cols={drop_cols}")

    test_pred_pro=test_pred_pro.mean(axis=0)
    
    oof_pred_sorted=sorted(oof_pred)
    margin=[0,oof_pred_sorted[int(len(oof_pred_sorted)*0.58)],
     oof_pred_sorted[int(len(oof_pred_sorted)*0.85)],oof_pred_sorted[int(len(oof_pred_sorted)*0.99)],1]
    for i in range(len(margin)-1):
        oof_index= np.where((oof_pred >= margin[i]) & (oof_pred < margin[i+1]))[0]
        oof_pred[oof_index]=i
        test_index= np.where((test_pred_pro >= margin[i]) & (test_pred_pro < margin[i+1]))[0]
        test_pred_pro[test_index]=i
    
    print(f"weighted kappa:{metric(y.values.reshape(-1).astype(np.int8),oof_pred.astype(np.int8))}")
     
    return oof_pred,test_pred_pro

# lgb_params={
#         "boosting_type": "gbdt",'objective':'binary',"metric": "auc",
#         'random_state': 2024, 'n_estimators': 512, 
#         'learning_rate': 0.07975474666326936, 'max_depth': 10, 'num_leaves': 207,
#         'min_data_in_leaf': 41,'feature_fraction': 0.6385678848225935, 
#         'bagging_fraction': 0.9042038292349021, 'bagging_freq': 6, 
#         'lambda_l1': 9.920617415343463, 'lambda_l2': 4.351491475117983,
#         'reg_alpha': 0.006329813118558037, 'reg_lambda': 0.22366541275310856,
#         'colsample_bytree': 0.9045121369263609, 'subsample': 0.6560250299728694,
#         'min_child_samples': 16,"verbose": -1,
# }


lgb_params = {
    "boosting_type": "gbdt",
    'random_state': 2024,
    'objective': 'multiclass',
    'num_class': 4,
    "verbose": -1,
    'feature_fraction': 0.6385678848225935,
    
    'n_estimators': 256,
    'learning_rate': 0.013579256659883413,
    'max_depth': 4,
    'num_leaves': 61,
    'min_data_in_leaf': 15,
    'bagging_fraction': 0.4724962272858123,
    'bagging_freq': 1,
    'lambda_l1': 0.5610890263591135,
    'lambda_l2': 5.471842497266317,
    'reg_alpha': 0.8138178726121249,
    'reg_lambda': 0.7707264717911311,
    'colsample_bytree': 0.9024157827642343,
    'subsample': 0,
    'min_child_samples': 45

}



lgb_oof_pred_pro,lgb_test_pro=fit_and_predict(model=LGBMClassifier(**lgb_params),num_folds=Config.num_folds,name='lgb')
print(f"lgb_test_pro[:10]:{lgb_test_pro[:10]}")
# Out:
# len(choose_cols):194
# name lgb,fold:0
# [100]	valid_0's multi_logloss: 0.565416
# [200]	valid_0's multi_logloss: 0.544526
# drop_cols=['FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone', 'PAQ_A-Season', 'stat_1', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_39', 'stat_41', 'stat_42', 'stat_43', 'stat_44', 'stat_45', 'stat_46', 'stat_53', 'stat_57', 'stat_58', 'stat_64', 'stat_65', 'stat_67', 'stat_69', 'stat_70', 'stat_77', 'stat_81', 'stat_82', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Winter', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Fall', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Winter', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Fall', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Winter', 'SDS-Season_Fall', 'SDS-Season_Summer', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Winter', 'PreInt_EduHx-Season_Summer']
# name lgb,fold:1
# [100]	valid_0's multi_logloss: 0.579646
# [200]	valid_0's multi_logloss: 0.568915
# drop_cols=['Basic_Demos-Enroll_Season', 'FGC-FGC_GSND_Zone', 'PAQ_A-Season', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_14', 'stat_17', 'stat_22', 'stat_39', 'stat_41', 'stat_42', 'stat_43', 'stat_44', 'stat_45', 'stat_46', 'stat_53', 'stat_57', 'stat_58', 'stat_62', 'stat_64', 'stat_65', 'stat_69', 'stat_70', 'stat_71', 'stat_77', 'stat_81', 'stat_82', 'stat_83', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Winter', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Fall', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Winter', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Fall', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Winter', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Winter', 'SDS-Season_Fall', 'SDS-Season_Summer', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Summer']
# name lgb,fold:2
# [100]	valid_0's multi_logloss: 0.56327
# [200]	valid_0's multi_logloss: 0.550442
# drop_cols=['FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone', 'PAQ_A-Season', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_14', 'stat_17', 'stat_39', 'stat_41', 'stat_42', 'stat_44', 'stat_45', 'stat_46', 'stat_53', 'stat_55', 'stat_57', 'stat_58', 'stat_60', 'stat_64', 'stat_65', 'stat_69', 'stat_70', 'stat_76', 'stat_77', 'stat_81', 'stat_82', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'stat_95', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Winter', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Fall', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Fall', 'Physical-Season_Winter', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Winter', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Winter', 'SDS-Season_Fall', 'SDS-Season_Summer', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Summer']
# name lgb,fold:3
# [100]	valid_0's multi_logloss: 0.598006
# [200]	valid_0's multi_logloss: 0.594903
# drop_cols=['FGC-FGC_GSD_Zone', 'BIA-BIA_Frame_num', 'stat_1', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_15', 'stat_17', 'stat_39', 'stat_41', 'stat_42', 'stat_43', 'stat_44', 'stat_45', 'stat_46', 'stat_50', 'stat_52', 'stat_53', 'stat_55', 'stat_57', 'stat_58', 'stat_62', 'stat_64', 'stat_65', 'stat_69', 'stat_70', 'stat_75', 'stat_77', 'stat_81', 'stat_82', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Fall', 'Physical-Season_Winter', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Winter', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Fall', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Winter', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Fall', 'SDS-Season_Summer', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Summer']
# name lgb,fold:4
# [100]	valid_0's multi_logloss: 0.590524
# [200]	valid_0's multi_logloss: 0.581352
# drop_cols=['FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone', 'FGC-FGC_TL_Zone', 'BIA-BIA_Frame_num', 'PAQ_A-Season', 'stat_1', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_17', 'stat_39', 'stat_41', 'stat_42', 'stat_43', 'stat_44', 'stat_45', 'stat_46', 'stat_52', 'stat_53', 'stat_55', 'stat_57', 'stat_58', 'stat_64', 'stat_65', 'stat_69', 'stat_70', 'stat_71', 'stat_77', 'stat_79', 'stat_81', 'stat_82', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Fall', 'Physical-Season_Winter', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Winter', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Fall', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Winter', 'SDS-Season_Summer', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Summer']
# name lgb,fold:5
# [100]	valid_0's multi_logloss: 0.573642
# [200]	valid_0's multi_logloss: 0.566198
# drop_cols=['Fitness_Endurance-Max_Stage', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone', 'FGC-FGC_TL_Zone', 'BIA-BIA_Frame_num', 'PAQ_A-Season', 'stat_0', 'stat_1', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_17', 'stat_39', 'stat_41', 'stat_42', 'stat_44', 'stat_45', 'stat_46', 'stat_53', 'stat_55', 'stat_57', 'stat_58', 'stat_62', 'stat_64', 'stat_65', 'stat_69', 'stat_70', 'stat_76', 'stat_77', 'stat_81', 'stat_82', 'stat_83', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Winter', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Fall', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Fall', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Winter', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Winter', 'SDS-Season_Fall', 'SDS-Season_Summer', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Winter', 'PreInt_EduHx-Season_Summer']
# name lgb,fold:6
# [100]	valid_0's multi_logloss: 0.559074
# [200]	valid_0's multi_logloss: 0.5481
# drop_cols=['FGC-FGC_GSD_Zone', 'FGC-FGC_TL_Zone', 'BIA-BIA_FFM', 'PAQ_A-Season', 'stat_1', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_14', 'stat_15', 'stat_39', 'stat_41', 'stat_42', 'stat_43', 'stat_44', 'stat_45', 'stat_46', 'stat_53', 'stat_57', 'stat_58', 'stat_62', 'stat_65', 'stat_69', 'stat_70', 'stat_71', 'stat_77', 'stat_81', 'stat_82', 'stat_83', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Winter', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Fall', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Fall', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Winter', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Fall', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Winter', 'SDS-Season_Fall', 'SDS-Season_Summer', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Summer']
# name lgb,fold:7
# [100]	valid_0's multi_logloss: 0.578315
# [200]	valid_0's multi_logloss: 0.565501
# drop_cols=['FGC-FGC_CU_Zone', 'FGC-FGC_GSD_Zone', 'BIA-BIA_Frame_num', 'PAQ_A-Season', 'stat_1', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_15', 'stat_17', 'stat_22', 'stat_39', 'stat_41', 'stat_42', 'stat_43', 'stat_44', 'stat_45', 'stat_46', 'stat_50', 'stat_53', 'stat_55', 'stat_57', 'stat_58', 'stat_64', 'stat_65', 'stat_67', 'stat_69', 'stat_70', 'stat_77', 'stat_81', 'stat_82', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Winter', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Winter', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Winter', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Fall', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Winter', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Fall', 'SDS-Season_Summer', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Summer']
# name lgb,fold:8
# [100]	valid_0's multi_logloss: 0.569665
# [200]	valid_0's multi_logloss: 0.559186
# drop_cols=['FGC-FGC_GSND_Zone', 'FGC-FGC_GSD_Zone', 'PAQ_A-Season', 'stat_1', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_39', 'stat_41', 'stat_42', 'stat_43', 'stat_44', 'stat_45', 'stat_46', 'stat_47', 'stat_53', 'stat_55', 'stat_57', 'stat_58', 'stat_59', 'stat_64', 'stat_65', 'stat_69', 'stat_70', 'stat_71', 'stat_77', 'stat_79', 'stat_81', 'stat_82', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Winter', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Fall', 'Physical-Season_Winter', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Winter', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Fall', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Winter', 'SDS-Season_Fall', 'SDS-Season_Summer', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Summer']
# name lgb,fold:9
# [100]	valid_0's multi_logloss: 0.583806
# [200]	valid_0's multi_logloss: 0.571106
# drop_cols=['FGC-FGC_GSD_Zone', 'FGC-FGC_SRL_Zone', 'BIA-BIA_Frame_num', 'PAQ_A-Season', 'stat_1', 'stat_2', 'stat_3', 'stat_4', 'stat_5', 'stat_6', 'stat_7', 'stat_8', 'stat_9', 'stat_10', 'stat_11', 'stat_20', 'stat_39', 'stat_41', 'stat_42', 'stat_43', 'stat_44', 'stat_45', 'stat_46', 'stat_50', 'stat_52', 'stat_53', 'stat_57', 'stat_58', 'stat_62', 'stat_64', 'stat_65', 'stat_69', 'stat_70', 'stat_71', 'stat_77', 'stat_81', 'stat_82', 'stat_89', 'stat_92', 'stat_93', 'stat_94', 'Basic_Demos-Enroll_Season_Spring', 'Basic_Demos-Enroll_Season_Fall', 'Basic_Demos-Enroll_Season_Summer', 'CGAS-Season_Spring', 'CGAS-Season_Summer', 'CGAS-Season_Winter', 'Physical-Season_Spring', 'Physical-Season_Fall', 'Physical-Season_Summer', 'Fitness_Endurance-Season_Spring', 'Fitness_Endurance-Season_Winter', 'Fitness_Endurance-Season_Fall', 'FGC-Season_Spring', 'FGC-Season_Summer', 'FGC-Season_Fall', 'FGC-Season_Winter', 'BIA-Season_Summer', 'BIA-Season_Fall', 'BIA-Season_Spring', 'BIA-Season_Winter', 'PAQ_A-Season_Winter', 'PAQ_A-Season_Summer', 'PAQ_A-Season_Spring', 'PAQ_A-Season_Fall', 'PAQ_C-Season_Spring', 'PAQ_C-Season_Summer', 'PAQ_C-Season_Fall', 'SDS-Season_Spring', 'SDS-Season_Winter', 'SDS-Season_Fall', 'PreInt_EduHx-Season_Spring', 'PreInt_EduHx-Season_Fall', 'PreInt_EduHx-Season_Summer']
# weighted kappa:0.46659791254511984
# lgb_test_pro[:10]:[0. 0. 1. 0. 1. 1. 0. 0. 1. 1.]

# %% [markdown]
# # submission

# %%
submission=pd.read_csv("/kaggle/input/child-mind-institute-problematic-internet-use/sample_submission.csv")
submission[Config.TARGET_NAME]=lgb_test_pro.astype(int)
submission.to_csv("/kaggle/working/submission.csv",index=None)
# print(submission)
